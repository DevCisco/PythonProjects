# %%
import pandas as PD
import matplotlib 
voti={'User1':[30,18,25,21],'User2':[25,30,24,28],'User3':[19,20,27,19]}
voto=PD.DataFrame(voti)
print(voto.describe())
print(voto.hist())
# Out:
#        Francesco   Fredrick   Abraham
# count   4.000000   4.000000   4.00000
# mean   23.500000  26.750000  21.25000
# std     5.196152   2.753785   3.86221
# min    18.000000  24.000000  19.00000
# 25%    20.250000  24.750000  19.00000
# 50%    23.000000  26.500000  19.50000
# 75%    26.250000  28.500000  21.75000
# max    30.000000  30.000000  27.00000
# [[<Axes: title={'center': 'Francesco'}>
#   <Axes: title={'center': 'Fredrick'}>]
#  [<Axes: title={'center': 'Abraham'}> <Axes: >]]
